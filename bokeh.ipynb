# %%
from bokeh.plotting import figure, output_file, show, save, ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Viridis10
from bokeh.embed import components
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\lrmks\Downloads\Number of Illiterates in Urban Telangana.csv")

# %%
df
# Out:
#      District     Mandal Muncipality            WardName  female    male  \
# 0     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  1  1119.0   597.0
# 1     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  2   677.0   429.0
# 2     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  3   323.0   137.0
# 3     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  4   451.0   230.0
# 4     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  5   253.0   101.0
# 5     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  6   235.0    63.0
# 6     ADILABAD  ADILABAD    Adilabad  Revenue Ward No  7   119.0    23.0
# 7     ADILABAD  ADILABAD    Adilabad  Revenue Ward No 10   204.0    74.0
# 8     ADILABAD  ADILABAD    Adilabad  Revenue Ward No 11   332.0   160.0
# 9     ADILABAD  ADILABAD    Adilabad  Revenue Ward No 12   362.0   231.0
# 10    ADILABAD  ADILABAD    Adilabad  Revenue Ward No 13   576.0   400.0
# 11    ADILABAD  ADILABAD    Adilabad  Revenue Ward No 14   483.0   279.0
# ...

# %%
adilabad= df[df[ 'District ']=='ADILABAD']

# %%
adilabad
# Out:
#     District     Mandal Muncipality            WardName  female   male  \
# 0    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  1  1119.0  597.0
# 1    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  2   677.0  429.0
# 2    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  3   323.0  137.0
# 3    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  4   451.0  230.0
# 4    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  5   253.0  101.0
# 5    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  6   235.0   63.0
# 6    ADILABAD  ADILABAD    Adilabad  Revenue Ward No  7   119.0   23.0
# 7    ADILABAD  ADILABAD    Adilabad  Revenue Ward No 10   204.0   74.0
# 8    ADILABAD  ADILABAD    Adilabad  Revenue Ward No 11   332.0  160.0
# 9    ADILABAD  ADILABAD    Adilabad  Revenue Ward No 12   362.0  231.0
# 10   ADILABAD  ADILABAD    Adilabad  Revenue Ward No 13   576.0  400.0
# 11   ADILABAD  ADILABAD    Adilabad  Revenue Ward No 14   483.0  279.0
# ...

# %%
adilabad.dropna()
# Out:
#     District        Mandal  Muncipality             WardName  female   male  \
# 0    ADILABAD     ADILABAD     Adilabad   Revenue Ward No  1  1119.0  597.0
# 1    ADILABAD     ADILABAD     Adilabad   Revenue Ward No  2   677.0  429.0
# 2    ADILABAD     ADILABAD     Adilabad   Revenue Ward No  3   323.0  137.0
# 8    ADILABAD     ADILABAD     Adilabad   Revenue Ward No 11   332.0  160.0
# 10   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 13   576.0  400.0
# 11   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 14   483.0  279.0
# 12   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 15   748.0  428.0
# 14   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 17   158.0   71.0
# 15   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 18   288.0  116.0
# 16   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 19   674.0  314.0
# 19   ADILABAD     ADILABAD     Adilabad   Revenue Ward No 22   213.0   78.0
# ...

# %%
source = ColumnDataSource(adilabad)
print(source)

output_file('adilabad.html')
# Out:
# ColumnDataSource(id='1008', ...)

# %%
plot = figure(
    y_range=crop_list,
    plot_width=800,
    plot_height=600,
    title='adilabad',
    x_axis_label='male',
    y_axis_label='m'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9407c1ad597a> in <module>
#       1 plot = figure(
# ----> 2     y_range=crop_list,
#       3     plot_width=800,
#       4     plot_height=600,
#       5     title='adilabad',
#
# NameError: name 'crop_list' is not defined
